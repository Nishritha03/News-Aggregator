# %%
# !pip install requests bs4  pandas
# Out:
# Requirement already satisfied: requests in c:\users\admin\anaconda3\lib\site-packages (2.32.2)
# Requirement already satisfied: bs4 in c:\users\admin\anaconda3\lib\site-packages (0.0.2)
# Requirement already satisfied: pandas in c:\users\admin\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests) (2024.7.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\admin\anaconda3\lib\site-packages (from bs4) (4.12.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\admin\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.5)

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

all_urls = []
url = 'https://www.cnn.com'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

for a in soup.find_all('a', href=True):   #retriving all the urls in the cnn news 
    href = a['href']
    
    full_url = urljoin(url, href)  # Using urljoin to handle both relative and absolute URLs
    if full_url not in all_urls:  # Avoid duplicate URLs
        all_urls.append(full_url)

print(all_urls)

# %%
#importing the required libraries
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import csv
from textblob import TextBlob
import uuid

def url_is_article_cnn(url, current_year='2024'):   #function to check if the URL is a CNN article
    return url and f'cnn.com/{current_year}/' in url and '/gallery/' not in url

def url_is_article_indiatoday(url):   #function to check if the ur is a IndiaToday article
    return url and 'https://www.indiatoday.in/' in url and '/story/' in url

def extract_article_urls(page_url, is_cnn=True, current_year='2024'): #this extracts articles url from the webpage
    try:
        response = requests.get(page_url, timeout=30)
        response.raise_for_status()
    except requests.RequestException as e:
        print(f"Error fetching {page_url}: {e}")
        return []

    soup = BeautifulSoup(response.text, 'html.parser')
    all_links = soup.find_all('a', href=True)

    article_urls = []
    for link in all_links:
        full_url = urljoin(page_url, link['href'])
        if is_cnn:
            if url_is_article_cnn(full_url, current_year) and full_url not in article_urls:
                article_urls.append(full_url)
        else:
            if url_is_article_indiatoday(full_url) and full_url not in article_urls:
                article_urls.append(full_url)
    
    return article_urls

def scrape_cnn_article(article_url):   #scraping a CNN article
    try:                                                         
        response = requests.get(article_url, timeout=30)
        response.raise_for_status()
    except requests.RequestException as e:
        print(f"Error fetching {article_url}: {e}")
        return {}

    soup = BeautifulSoup(response.text, 'html.parser')  # Parse the HTML content of the page using BeautifulSoup with the built-in HTML parser

    title_tag = soup.find('h1')
    title = title_tag.get_text(strip=True) if title_tag else 'No title found'

    summary_tag = soup.find('div', class_='article__content-container')
    if summary_tag:
        summary_text = ' '.join(p.get_text(strip=True) for p in summary_tag.find_all('p'))
    else:
        summary_meta = soup.find('meta', attrs={"name": "description"}) or soup.find('meta', attrs={"property": "og:description"})
        summary_text = summary_meta.get('content', 'No summary found') if summary_meta else 'No summary found'

    summary_sentences = summary_text.split('. ')
    summary = '. '.join(summary_sentences[:2]) + '.' if len(summary_sentences) > 1 else summary_text

    date_tag = soup.find('meta', {'property': 'article:published_time'})
    pub_date = date_tag.get('content', 'No date found') if date_tag else 'No date found'

    return {    
        'title': title,
        'summary': summary,
        'publication_date': pub_date,
        'source': 'CNN',
        'url': article_url
    }

def scrape_india_today_article(article_url):   #scraping the indiatoday articles.
    try:
        response = requests.get(article_url, timeout=30)
        response.raise_for_status()
    except requests.RequestException as e:
        print(f"Error fetching {article_url}: {e}")
        return {}

    soup = BeautifulSoup(response.text, 'html.parser')

    title_tag = soup.find('h1')
    title = title_tag.get_text(strip=True) if title_tag else 'No title found'

    summary_tag = soup.find('div', class_='Story_description__fq_4S description paywall')
    if summary_tag:
        summary_text = ' '.join(p.get_text(strip=True) for p in summary_tag.find_all('p'))
    else:
        summary_meta = soup.find('meta', attrs={"name": "description"}) or soup.find('meta', attrs={"property": "og:description"})
        summary_text = summary_meta.get('content', 'No summary found') if summary_meta else 'No summary found'

    summary_sentences = summary_text.split('. ')
    summary = '. '.join(summary_sentences[:2]) + '.' if len(summary_sentences) > 1 else summary_text

    pub_date_tag = soup.find('span', class_='jsx-ace90f4eca22afc7 strydate')
    pub_date = pub_date_tag.get_text(strip=True) if pub_date_tag else 'No date found'

    return {
        'title': title,
        'summary': summary,
        'publication_date': pub_date,
        'source': 'India Today',
        'url': article_url
    }

def categorize_article(text):
    """
    Categorizes an article based on its text content using keywords and TextBlob.
    """
    text_blob = TextBlob(text.lower())
    categories = {
        'Politics': ['government', 'election', 'policy', 'parliament'],
        'Technology': ['technology', 'software', 'hardware', 'innovation'],
        'Sports': ['sports', 'tournament', 'player', 'match'],
        'Finance': ['economy', 'market', 'finance', 'stock'],
        'Health': ['health', 'medicine', 'disease', 'wellness'],
        'Science': ['science', 'research', 'discovery', 'experiment'],
        'Entertainment': ['entertainment', 'celebrity', 'movie', 'music'],
        'Environment': ['environment', 'climate', 'pollution', 'wildlife'],
        'Education': ['education', 'university', 'school', 'learning'],
        'Business': ['business', 'corporate', 'industry', 'startup'],
        'Travel': ['travel', 'tourism', 'destination', 'hotel'],
        'Food': ['food', 'cuisine', 'restaurant', 'recipe'],
        'Fashion': ['fashion', 'style', 'clothing', 'designer']
    }

    for category, keywords in categories.items():
        if any(word in text_blob.words for word in keywords):
            return category
    
    return 'Other'  #if the category is not present in the above mentioned then returns the other category

def scrape_and_save_articles(page_urls, output_csv, current_year='2024'): #Scrapes articles from the provided page URLs and saves their details to a CSV file.
    seen_urls = set()
    id_counter = 1  # Initializing ID counter

    with open(output_csv, mode='w', newline='', encoding='utf-8') as file:
        fieldnames = ['id', 'title', 'summary', 'publication_date', 'source', 'url', 'category']
        writer = csv.DictWriter(file, fieldnames=fieldnames)
        writer.writeheader()

        for page_url in page_urls:
            is_cnn = 'cnn.com' in page_url
            article_urls = extract_article_urls(page_url, is_cnn, current_year)
            if not article_urls:
                print(f"No articles found or an error occurred while processing {page_url}.")
                continue
            
            for url in article_urls:
                if url in seen_urls:
                    continue  # Skip duplicates
                
                if 'cnn.com' in url:
                    article_info = scrape_cnn_article(url)
                elif 'indiatoday.in' in url:
                    article_info = scrape_india_today_article(url)
                else:
                    continue  # Skip URLs that are not from CNN or India Today

                if article_info:
                    # Check if publication date is valid
                    if article_info['publication_date'] == 'No date found':
                        print(f"Skipped due to missing date: {url}")
                        continue

                    article_info['category'] = categorize_article(article_info['summary'])
                    article_info['id'] = id_counter  # Assign ID
                    writer.writerow(article_info)
                    seen_urls.add(url)
                    print(f"Saved: {url}")

                    id_counter += 1  # Increment ID counter
                else:
                    print(f"Skipped: {url}")


if __name__ == "__main__":
    page_urls = [
        'https://www.cnn.com/',  
        'https://www.indiatoday.in/'  
    ]
    output_csv = 'news_articles.csv'
    scrape_and_save_articles(page_urls, output_csv)
    print(f"Finished! Articles saved to {output_csv}")
# Out:
# Saved: https://www.cnn.com/2024/09/03/europe/ukraine-poltava-russia-attack-intl/index.html
# Saved: https://www.cnn.com/2024/09/03/middleeast/hamas-israel-hostage-deal-raise-stakes-intl/index.html
# Saved: https://www.cnn.com/2024/09/03/style/china-detains-artist-gao-brothers-mao-intl-hnk/index.html
# Saved: https://www.cnn.com/2024/09/03/food/honey-deuce-us-open-cocktail-popularity/index.html
# Saved: https://www.cnn.com/2024/09/03/health/chair-yoga-flexibility-stress-relief-wellness/index.html
# Saved: https://www.cnn.com/2024/09/03/sport/morteza-mehrzadselakjani-sleep-paralympics-spt-intl/index.html
# Saved: https://www.cnn.com/2024/09/03/asia/bangladesh-house-mirrors-detention-center-intl-hnk-dst/index.html
# Saved: https://www.cnn.com/2024/09/03/world/video/bangladesh-hasina-regime-coren-live-09031aseg2-cnni-world-fast
# Saved: https://www.cnn.com/2024/08/12/asia/bangladesh-quota-protests-student-martyr-intl-hnk-dst/index.html
# Saved: https://www.cnn.com/2024/08/07/asia/muhammad-yunus-bangladesh-government-intl-hnk/index.html
# Saved: https://www.cnn.com/2024/09/03/cars/global-automakers-china-retreat-hnk-intl/index.html
# Saved: https://www.cnn.com/2024/09/03/china/china-africa-summit-intl-hnk/index.html
# Saved: https://www.cnn.com/2024/09/03/us/linda-sun-former-hochul-staff-arrest/index.html
# Saved: https://www.cnn.com/2024/09/03/us/new-york-linda-sun-china-gifts/index.html
# Saved: https://www.cnn.com/2024/09/03/politics/jimmy-mccain-decries-trump-arlington-appearance/index.html
# Saved: https://www.cnn.com/2024/09/03/politics/trump-fact-checking-analysis/index.html
# Saved: https://www.cnn.com/2024/09/03/world/video/russian-strike-facility-ukraine-pleitgen-digvid
# Saved: https://www.cnn.com/2024/09/04/australia/iran-summons-ambassador-over-social-post-intl-hnk/index.html
# Saved: https://www.cnn.com/2024/09/04/tech/brazil-lula-elon-musk-x-suspension-hnk-intl/index.html
# Saved: https://www.cnn.com/2024/09/03/world/video/video-us-marines-turkey-assaulted-digvid
# Saved: https://www.cnn.com/2024/09/03/americas/christmas-venezuela-october-maduro-intl-latam/index.html
# Saved: https://www.cnn.com/2024/09/03/world/video/remembering-hersh-goldberg-polin-ac360-digvid
# Saved: https://www.cnn.com/2024/09/03/travel/swiss-airline-first-class-seats-too-heavy/index.html
# Saved: https://www.cnn.com/2024/09/02/politics/us-marines-turkey-assault/index.html
# Saved: https://www.cnn.com/2024/09/03/europe/english-channel-migrant-boat-deaths-intl/index.html
# Saved: https://www.cnn.com/2024/09/03/science/video/boeing-starliner-noise-iss-cnc-fisher-digvid
# Saved: https://www.cnn.com/2024/09/03/business/hewlett-packard-uk-claim-mike-lynch/index.html
# Saved: https://www.cnn.com/2024/09/03/style/jennifer-garner-home-ad/index.html
# Saved: https://www.cnn.com/2024/09/03/australia/yacht-rescue-off-nsw-coast-intl-hnk/index.html
# Saved: https://www.cnn.com/2024/09/03/africa/dr-congo-prison-break-intl/index.html
# Saved: https://www.cnn.com/2024/09/03/style/video/new-york-moma-quest-qmb-digvid
# Saved: https://www.cnn.com/2024/09/02/asia/pope-catholic-church-pivot-asia-hnk-intl/index.html
# Saved: https://www.cnn.com/2024/09/03/sport/armless-archers-viral-paralympics-spt-intl/index.html
# Saved: https://www.cnn.com/2024/09/03/sport/oksana-masters-paralympics-coy-wire-intl-spt/index.html
# Saved: https://www.cnn.com/2024/09/03/climate/sea-level-rise-antarctica-robots/index.html
# Saved: https://www.cnn.com/2024/09/02/entertainment/richard-gere-julia-roberts-pretty-woman/index.html
# Saved: https://www.cnn.com/2024/09/03/sport/aryna-sabalenka-zheng-qinwen-us-open-spt-intl/index.html
# Saved: https://www.cnn.com/2024/09/02/world/video/camp-humphreys-military-base-south-korea-ldn-digvid
# Saved: https://www.cnn.com/2024/09/02/science/titanic-photos-show-major-decay-intl-scli/index.html
# Saved: https://www.cnn.com/2024/08/28/science/underwater-mountain-seamount-nazca-ridge/index.html
# Saved: https://www.cnn.com/2024/08/31/science/dimorphos-dart-impact-debris-meteor-shower/index.html
# Saved: https://www.cnn.com/2024/08/30/science/ancient-submerged-cave-bridge-mallorca/index.html
# Saved: https://www.cnn.com/2024/08/27/science/webb-nebula-rogue-worlds/index.html
# Saved: https://www.cnn.com/2024/08/31/travel/travel-news-eu-passport-best-connected-airport/index.html
# Saved: https://www.cnn.com/2024/09/03/business/costco-membership-fee-price-increase/index.html
# Saved: https://www.cnn.com/2024/09/03/business/chase-tiktok-trend/index.html
# Saved: https://www.cnn.com/2024/09/03/economy/college-jobs-blue-collar-workers/index.html
# Saved: https://www.cnn.com/2024/09/02/business/hotel-strike/index.html
# Saved: https://www.cnn.com/2024/09/01/business/thousands-of-us-hotel-workers-strike-as-contract-negotiations-stall/index.html
# Saved: https://www.cnn.com/2024/08/30/style/venice-film-festival-2024-red-carpet/index.html
# Saved: https://www.cnn.com/2024/06/12/style/jack-lueders-booth-female-prisoners/index.html
# Saved: https://www.cnn.com/2024/09/02/style/israel-haifa-museum-boy-broken-jar-returns-intl-hnk/index.html
# Saved: https://www.cnn.com/2024/09/01/style/crop-tops-middle-age-essay/index.html
# Saved: https://www.cnn.com/2024/08/29/style/south-korea-k-pop-idols-tv-show-intl-hnk/index.html
# Saved: https://www.cnn.com/2024/09/02/sport/scottie-scheffler-tour-championship-2024-spt-intl/index.html
# Saved: https://www.cnn.com/2024/09/02/sport/usc-lsu-vegas-kickoff-classic-football-spt-intl/index.html
# Saved: https://www.cnn.com/2024/09/01/sport/charles-leclerc-ferrari-italian-grand-prix-spt-intl/index.html
# Saved: https://www.cnn.com/2024/09/01/sport/joey-chestnut-takeru-kobayashi-hot-dog-eating-spt/index.html
# Saved: https://www.cnn.com/2024/09/03/politics/trump-guilty-plea-january-6-charges-smith/index.html
# Saved: https://www.cnn.com/2024/09/03/politics/ketanji-brown-jackson-new-memoir/index.html
# Saved: https://www.cnn.com/2024/09/03/politics/harris-economic-proposals/index.html
# Saved: https://www.cnn.com/2024/09/02/politics/andrew-cuomo-testify-covid-hearing/index.html
# Saved: https://www.cnn.com/2024/09/03/politics/trump-quest-destroy-harris-momentum/index.html
# Saved: https://www.cnn.com/2024/09/02/health/phones-allowed-school-children-wellness/index.html
# Saved: https://www.cnn.com/2024/09/01/health/emotional-eating-wellness/index.html
# Saved: https://www.cnn.com/2024/08/31/health/ketamine-effects-matthew-perry-wellness/index.html
# Saved: https://www.cnn.com/2024/09/01/health/parenting-stress-tips-surgeon-general-wellness/index.html
# Saved: https://www.cnn.com/2024/08/27/health/colostrum-supplements-pros-cons-wellness/index.html
# Saved: https://www.cnn.com/2024/09/03/tech/facebook-spam-ai-meta/index.html
# Saved: https://www.cnn.com/2024/09/03/media/elon-musk-x-kamala-harris-trump-misinformation/index.html
# Saved: https://www.cnn.com/2024/08/22/tech/china-drone-delivery-great-wall-intl-hnk/index.html
# Saved: https://www.cnn.com/2024/08/15/tech/elon-musk-x-grok-ai-images/index.html
# Saved: https://www.cnn.com/2024/08/30/business/brazil-suspends-x-elon-musk-moraes-intl-hnk/index.html
# Saved: https://www.cnn.com/2024/09/02/politics/kamala-harris-us-steel/index.html
# Saved: https://www.cnn.com/2024/09/01/climate/klamath-dam-salmon/index.html
# Saved: https://www.cnn.com/2024/08/31/science/underwater-mountain-wonder-theory-science-newsletter/index.html
# Saved: https://www.cnn.com/2024/08/30/science/space-x-falcon-9-rocket-faa-clearance/index.html
# Saved: https://www.cnn.com/2024/09/03/europe/france-rape-trial-intl-latam/index.html
# Saved: https://www.indiatoday.in/india/story/indian-airlines-ic-814-survivors-ordeal-plane-hijack-netflix-series-bhola-shankar-terrorists-names-2593249-2024-09-04
# Saved: https://www.indiatoday.in/sports/paralympics/story/paris-paralympics-2024-day-6-india-medal-tally-ajeet-singh-sharad-kumar-deepthi-jeevanji-2593208-2024-09-04
# Saved: https://www.indiatoday.in/movies/regional-cinema/story/nivin-pauly-sexual-assault-charges-conspiracy-fake-complaint-2593252-2024-09-04
# Saved: https://www.indiatoday.in/india/story/exclusive-former-raw-chief-as-dulat-explains-indecisions-over-ic-814-hijacking-2593151-2024-09-03
# Saved: https://www.indiatoday.in/lifestyle/food/story/is-a-food-product-unsafe-to-eat-beyond-its-expiry-date-2592896-2024-09-04
# Saved: https://www.indiatoday.in/india/story/kolkata-doctor-rape-medics-protest-bengal-murder-case-police-cp-vineet-goyal-2593075-2024-09-03
# Saved: https://www.indiatoday.in/law/story/mumbai-court-man-gets-pre-arrest-bail-in-rape-case-cites-live-in-relationship-agreement-2593146-2024-09-03
# Saved: https://www.indiatoday.in/india/story/shivaji-statue-collapse-sculptor-jaydeep-apte-missing-opposition-attack-mahayuti-2593065-2024-09-03
# Saved: https://www.indiatoday.in/india/story/aparna-yadav-appointed-vice-chairperson-uttar-pradesh-women-commission-2593256-2024-09-04?utm_source=hp_lead&utm_medium=it_web
# Saved: https://www.indiatoday.in/india/karnataka/story/kannada-actor-darshan-renukaswamy-murder-case-chargesheet-evidence-bengaluru-police-2593310-2024-09-04?utm_source=hp_lead&utm_medium=it_web
# Saved: https://www.indiatoday.in/india/story/prime-minister-narendra-modi-bilateral-talks-brunei-sultan-hassanal-bolkiah-commence-singapore-visit-2593289-2024-09-04?utm_source=hp_lead&utm_medium=it_web
# Saved: https://www.indiatoday.in/india/story/exclusive-former-raw-chief-as-dulat-explains-indecisions-over-ic-814-hijacking-2593151-2024-09-03?utm_source=hp_lead&utm_medium=it_web
# Saved: https://www.indiatoday.in/movies/regional-cinema/story/nivin-pauly-sexual-assault-charges-conspiracy-fake-complaint-2593252-2024-09-04?utm_source=hp_lead&utm_medium=it_web
# Saved: https://www.indiatoday.in/india/story/shivaji-statue-collapse-sculptor-jaydeep-apte-missing-opposition-attack-mahayuti-2593065-2024-09-03?utm_source=hp_lead&utm_medium=it_web
# Saved: https://www.indiatoday.in/horoscopes/story/horoscope-today-september-4-aries-taurus-gemini-cancer-leo-virgo-libra-scorpio-sagittarius-capricorn-aquarius-pisces-2592773-2024-09-04?utm_source=hp_lead&utm_medium=it_web
# Saved: https://www.indiatoday.in/information/story/september-2024-calendar-check-list-of-important-dates-holidays-festivals-and-events-in-september-festivals-in-september-2024-check-the-updated-list-2587953-2024-08-30?utm_source=hp_lead&utm_medium=it_web
# Saved: https://www.indiatoday.in/india/karnataka/story/seniors-bengaluru-college-student-refusing-shave-beard-case-filed-2593213-2024-09-04
# Saved: https://www.indiatoday.in/india/story/maharashtra-passenger-assaults-staff-at-air-india-express-counter-at-mumbai-airport-2593115-2024-09-03
# Saved: https://www.indiatoday.in/information/story/shillong-teer-result-today-04092024-first-and-second-round-result-2593326-2024-09-04
# Saved: https://www.indiatoday.in/business/story/india-services-sector-growth-5-moth-high-august-new-orders-key-factors-2593325-2024-09-04
# Saved: https://www.indiatoday.in/business/story/stock-market-opening-update-sensex-nifty-it-shares-coal-india-down-2593319-2024-09-04
# Saved: https://www.indiatoday.in/information/story/kolkata-ff-fatafat-result-today-september-04-check-fatafat-result-online-2593318-2024-09-04
# Saved: https://www.indiatoday.in/technology/news/story/after-years-of-gaslighting-users-marketing-firm-finally-acknowledges-that-phones-listen-in-on-conversations-2593317-2024-09-04
# Saved: https://www.indiatoday.in/elections/story/jammu-kashmir-assembly-elections-rahul-gandhi-congress-campaign-rallies-2593315-2024-09-04
# Saved: https://www.indiatoday.in/movies/celebrities/story/sushmita-sen-birthday-note-daughter-renee-alisah-sen-2593313-2024-09-04
# Saved: https://www.indiatoday.in/trending-news/story/zomato-agent-2-year-old-daughter-work-delhi-starbucks-employee-linkedin-post-2593311-2024-09-04
# Saved: https://www.indiatoday.in/india/karnataka/story/kannada-actor-darshan-renukaswamy-murder-case-chargesheet-evidence-bengaluru-police-2593310-2024-09-04
# Saved: https://www.indiatoday.in/technology/news/story/google-announces-5-new-features-for-android-users-heres-what-you-need-to-know-and-who-will-get-them-2593305-2024-09-04
# Saved: https://www.indiatoday.in/india/tamil-nadu/story/tamil-nadu-virudhunagar-woman-cop-assaulted-hair-pulled-during-protest-2593210-2024-09-04
# Saved: https://www.indiatoday.in/india-today-insight/story/from-the-india-today-archives-2000-ic-814-hijack-the-inside-story-of-negotiations-in-kandahar-2592921-2024-09-03
# Saved: https://www.indiatoday.in/india/story/enforcement-directorate-arrest-aap-leader-amanatullah-khan-2593239-2024-09-04
# Saved: https://www.indiatoday.in/sports/paralympics/story/india-at-paralympics-2024-day-7-schedule-archer-harvinder-singh-in-focus-2593204-2024-09-04
# Saved: https://www.indiatoday.in/sports/tennis/story/us-open-roger-federer-return-arthur-ashe-stadium-crowd-ovation-reaction-2593253-2024-09-04
# Saved: https://www.indiatoday.in/lifestyle/wellness/story/going-to-the-gym-on-vacation-is-tough-you-can-still-work-out-though-2592746-2024-09-03
# Saved: https://www.indiatoday.in/india/story/himachal-pradesh-assembly-introduces-bill-end-pensions-for-disqualified-defected-mlas-2593304-2024-09-04
# Saved: https://www.indiatoday.in/movies/celebrities/story/sidharth-malhotra-lilly-singh-dance-kar-gayi-chull-not-as-cute-as-alia-bhatt-2593303-2024-09-04
# Saved: https://www.indiatoday.in/india/story/prime-minister-narendra-modi-bilateral-talks-brunei-sultan-hassanal-bolkiah-commence-singapore-visit-2593289-2024-09-04
# Saved: https://www.indiatoday.in/cities/mumbai/story/mumbai-suv-hits-woman-in-malad-driver-arrested-he-took-injured-to-hospital-2593300-2024-09-04
# Saved: https://www.indiatoday.in/world/story/ketamine-queen-doctor-face-trial-in-march-matthew-perry-death-2593299-2024-09-04
# Saved: https://www.indiatoday.in/world/story/russian-missile-strike-poltava-dead-injured-ukraine-volodymyr-zelenskyy-2592898-2024-09-03?utm_source=hp_bottom_trending&utm_medium=it_web
# Saved: https://www.indiatoday.in/india/story/chhattisgarh-dantewada-naxalites-killed-encounter-injured-2592754-2024-09-03?utm_source=hp_bottom_trending&utm_medium=it_web
# Saved: https://www.indiatoday.in/india/story/west-bengal-anti-rape-bill-aparajita-woman-and-child-bill-introduced-mamata-banerjee-bjp-2592722-2024-09-03?utm_source=hp_bottom_trending&utm_medium=it_web
# Saved: https://www.indiatoday.in/india/story/pm-narendra-modi-visit-brunei-singapore-strengthen-ties-discuss-defence-trade-2592576-2024-09-03?utm_source=hp_bottom_trending&utm_medium=it_web
# Saved: https://www.indiatoday.in/india/story/netflix-india-content-head-monika-shergill-ic-814-kandahar-hijack-government-summoned-today-2592555-2024-09-03?utm_source=hp_bottom_trending&utm_medium=it_web
# Saved: https://www.indiatoday.in/music/story/i-am-safe-singer-ap-dhillons-post-after-shots-fired-outside-canada-home-2592608-2024-09-03?utm_source=hp_bottom_trending&utm_medium=it_web
# Saved: https://www.indiatoday.in/horoscopes/story/horoscope-today-september-3-aries-taurus-gemini-cancer-leo-virgo-libra-scorpio-sagittarius-capricorn-aquarius-pisces-2592164-2024-09-03?utm_source=hp_bottom_trending&utm_medium=it_web
# Saved: https://www.indiatoday.in/information/story/vishwakarma-puja-2024-know-date-puja-time-all-you-need-to-know-2590665-2024-08-30?utm_source=hp_bottom_latest&utm_medium=it_web
# Saved: https://www.indiatoday.in/information/story/ganesh-chaturthi-2024-date-time-fasting-rules-all-you-need-to-know-2590618-2024-08-30?utm_source=hp_bottom_latest&utm_medium=it_web
# Saved: https://www.indiatoday.in/information/story/september-2024-calendar-check-list-of-important-dates-holidays-festivals-and-events-in-september-festivals-in-september-2024-check-the-updated-list-2587953-2024-08-30?utm_source=hp_bottom_latest&utm_medium=it_web
# Finished! Articles saved to news_articles.csv
